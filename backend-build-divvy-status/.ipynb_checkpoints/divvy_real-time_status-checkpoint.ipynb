# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 3/17/2021


##################################################################################################

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\user1\anaconda3\envs\py38\lib\site-packages (2.9.4)

# %%
pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in c:\users\user1\anaconda3\envs\py38\lib\site-packages (8.4.3)
# Requirement already satisfied: elastic-transport<9,>=8 in c:\users\user1\anaconda3\envs\py38\lib\site-packages (from elasticsearch) (8.4.0)
# Requirement already satisfied: urllib3<2,>=1.26.2 in c:\users\user1\anaconda3\envs\py38\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (1.26.9)
# Requirement already satisfied: certifi in c:\users\user1\anaconda3\envs\py38\lib\site-packages (from elastic-transport<9,>=8->elasticsearch) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

es = Elasticsearch('http://localhost:9200')

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

# Extract the body of the reply
response_body = response.read()
response_stations_info = response_stations_info.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047118,
#                         'legacy_id': '393',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3acea44-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047125,
#                         'legacy_id': '561',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b22d3d-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047125,
#                         'legacy_id': '101',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a547b8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047125,
#                         'legacy_id': '172',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 3,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a72012-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047126,
#                         'legacy_id': '129',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a5d3bb-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047119,
#                         'legacy_id': '335',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aae35a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047128,
#                         'legacy_id': '15',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047127,
#                         'legacy_id': '378',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3acb1de-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047127,
#                         'legacy_id': '490',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 7,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3afd294-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047132,
#                         'legacy_id': '147',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a62fc9-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047131,
#                         'legacy_id': '467',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af5d1c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047130,
#                         'legacy_id': '643',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047131,
#                         'legacy_id': '327',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aabad8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047129,
#                         'legacy_id': '290',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 6,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a9f76a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047139,
#                         'legacy_id': '273',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a99d47-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047145,
#                         'legacy_id': '684',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'f0f9f5dc-3d3f-4a32-aa3e-b87566e44de9',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047142,
#                         'legacy_id': '28',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 2,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047143,
#                         'legacy_id': '657',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047144,
#                         'legacy_id': '678',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a60781db-2bec-4a15-a4a2-363297aefcec',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047145,
#                         'legacy_id': '687',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'e63300bd-4ca3-4255-adfd-522289d68b8a',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047146,
#                         'legacy_id': '374',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac9d43-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047139,
#                         'legacy_id': '544',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b1d532-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047138,
#                         'legacy_id': '700',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a21de1a5-f5bc-4b50-8a13-aa28b7dcfa95',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047141,
#                         'legacy_id': '551',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b1fa1c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047134,
#                         'legacy_id': '578',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2862e-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047147,
#                         'legacy_id': '564',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b23cb8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047147,
#                         'legacy_id': '407',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ad2d57-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047147,
#                         'legacy_id': '236',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a854bf-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047148,
#                         'legacy_id': '704',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 3,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '759171ce-f355-4740-948d-e14bb8f7dc0e',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047150,
#                         'legacy_id': '294',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aa0bb7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047149,
#                         'legacy_id': '484',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3afb401-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047153,
#                         'legacy_id': '458',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af2c5f-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047153,
#                         'legacy_id': '591',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2c87c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047157,
#                         'legacy_id': '538',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b13e66-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047161,
#                         'legacy_id': '353',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac3b03-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047167,
#                         'legacy_id': '197',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': 'a3a795d7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047167,
#                         'legacy_id': '261',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a965b2-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047163,
#                         'legacy_id': '131',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a5de24-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047173,
#                         'legacy_id': '95',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a528d0-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047173,
#                         'legacy_id': '135',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a5f5e6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047173,
#                         'legacy_id': '690',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '792ceba0-564f-4a2c-bcb5-90da781ffeef',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047173,
#                         'legacy_id': '318',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aa8ca0-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047174,
#                         'legacy_id': '441',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3addda0-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047174,
#                         'legacy_id': '13',
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047170,
#                         'legacy_id': '277',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a9b1d7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047171,
#                         'legacy_id': '479',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af9a83-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047167,
#                         'legacy_id': '184',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 2,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a75d8a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047168,
#                         'legacy_id': '457',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af2737-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047168,
#                         'legacy_id': '365',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac7444-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047179,
#                         'legacy_id': '58',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 9,
#                         'num_scooters_unavailable': 1,
#                         'station_id': 'a3a48d5c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047180,
#                         'legacy_id': '593',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2d2b7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047176,
#                         'legacy_id': '244',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a8804b-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047177,
#                         'legacy_id': '153',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a6c38e-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047181,
#                         'legacy_id': '304',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aa4017-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047181,
#                         'legacy_id': '427',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': 'a3ad95a7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047185,
#                         'legacy_id': '342',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ab86b6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047189,
#                         'legacy_id': '580',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2905a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047184,
#                         'legacy_id': '554',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b20960-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047188,
#                         'legacy_id': '451',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ae87fa-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047183,
#                         'legacy_id': '723',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'da9e6779-5056-4d45-bae3-9dc325ed2807',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047184,
#                         'legacy_id': '504',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b01a86-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047193,
#                         'legacy_id': '237',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a859c4-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666047196,
#                         'legacy_id': '26',
# ...
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662499189,
#                         'legacy_id': '1677249772289529866',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1677249772289529866',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662488326,
#                         'legacy_id': '1674190376985963172',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1674190376985963172',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511154,
#                         'legacy_id': '1683527957294958598',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1683527957294958598',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662483612,
#                         'legacy_id': '1674190239547009454',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190239547009454',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1656005856,
#                         'legacy_id': '1575949498093662914',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1575949498093662914',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1656005849,
#                         'legacy_id': '1594046418168009436',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 10,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1594046418168009436',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511130,
#                         'legacy_id': '1695776956346497674',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1695776956346497674',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662499155,
#                         'legacy_id': '1674190235252042148',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190235252042148',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662498659,
#                         'legacy_id': '1674190170827532590',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190170827532590',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486849,
#                         'legacy_id': '1674190557374589898',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190557374589898',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1656005862,
#                         'legacy_id': '1594046418168009438',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1594046418168009438',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662499196,
#                         'legacy_id': '1677249776584497168',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1677249776584497168',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1656005896,
#                         'legacy_id': '1594046456822715150',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1594046456822715150',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486462,
#                         'legacy_id': '1674190535899753382',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190535899753382',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662484222,
#                         'legacy_id': '1674190291086617090',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190291086617090',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662498427,
#                         'legacy_id': '1674190157942630672',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1674190157942630672',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486213,
#                         'legacy_id': '1674190492950080350',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190492950080350',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511992,
#                         'legacy_id': '1677249879663712418',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1677249879663712418',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662489425,
#                         'legacy_id': '1715846688321143644',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1715846688321143644',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662489397,
#                         'legacy_id': '1715823822654071770',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1715823822654071770',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1656005852,
#                         'legacy_id': '1563698701206292480',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1563698701206292480',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662512058,
#                         'legacy_id': '1674190591734328324',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190591734328324',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662513165,
#                         'legacy_id': '1674190634684001360',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190634684001360',
#                         'station_status': 'active'}]},
#  'last_updated': 1666047248,
#  'ttl': 5}

# %%
pprint(stations_info_json)
# Out:
# {'data': {'stations': [{'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3acdae2-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.78007963264,
#                         'legacy_id': '390',
#                         'lon': -87.6297463052,
#                         'name': 'Wentworth Ave & 63rd St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000025',
#                         'station_id': 'a3acdae2-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b2be3a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.954468,
#                         'legacy_id': '589',
#                         'lon': -87.749594,
#                         'name': 'Milwaukee Ave & Cuyler Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '16991',
#                         'station_id': 'a3b2be3a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a96aca-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.827059,
#                         'legacy_id': '262',
#                         'lon': -87.64572,
#                         'name': 'Halsted St & 37th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1307000161',
#                         'station_id': 'a3a96aca-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3af8123-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.96835449363,
#                         'legacy_id': '474',
#                         'lon': -87.7118306675,
#                         'name': 'Christiana Ave & Lawrence Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15615',
#                         'station_id': 'a3af8123-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a52df5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88461618962,
#                         'legacy_id': '96',
#                         'lon': -87.6445705849,
#                         'name': 'Desplaines St & Randolph St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15535',
#                         'station_id': 'a3a52df5-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90985465216731,
#                         'legacy_id': '16',
#                         'lon': -87.66993016004562,
#                         'name': 'Paulina Ave & North Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000037',
#                         'station_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a9c0f6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8378,
#                         'legacy_id': '280',
#                         'lon': -87.65114,
#                         'name': 'Morgan St & 31st St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1308000046',
#                         'station_id': 'a3a9c0f6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3af52bc-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9716,
#                         'legacy_id': '465',
#                         'lon': -87.650154,
#                         'name': 'Marine Dr & Ainslie St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1504000171',
#                         'station_id': 'a3af52bc-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3aaa68b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.969517,
#                         'legacy_id': '323',
#                         'lon': -87.654691,
#                         'name': 'Sheridan Rd & Lawrence Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1309000041',
#                         'station_id': 'a3aaa68b-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3aae35a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.831379,
#                         'legacy_id': '335',
#                         'lon': -87.618034,
#                         'name': 'Calumet Ave & 35th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13345',
#                         'station_id': 'a3aae35a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b3634c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884114,
#                         'legacy_id': '621',
#                         'lon': -87.654264,
#                         'name': 'Aberdeen St & Randolph St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '18062',
#                         'station_id': 'a3b3634c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3acea44-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.76550800581,
#                         'legacy_id': '393',
#                         'lon': -87.616917925,
#                         'name': 'Calumet Ave & 71st St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15599',
#                         'station_id': 'a3acea44-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a5d3bb-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.857556,
#                         'legacy_id': '129',
#                         'lon': -87.661535,
#                         'name': 'Blue Island Ave & 18th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13135',
#                         'station_id': 'a3a5d3bb-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3afd294-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.94524356848,
#                         'legacy_id': '490',
#                         'lon': -87.7066499009,
#                         'name': 'Troy St & Elston Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15631',
#                         'station_id': 'a3afd294-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858166,
#                         'legacy_id': '15',
#                         'lon': -87.656495,
#                         'name': 'Racine Ave & 18th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13164',
#                         'station_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a547b8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.78091096424803,
#                         'legacy_id': '101',
#                         'lon': -87.57632374763489,
#                         'name': '63rd St Beach',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15491',
#                         'station_id': 'a3a547b8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a72012-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90230870122,
#                         'legacy_id': '172',
#                         'lon': -87.627690528,
#                         'name': 'Rush St & Cedar St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1504000133',
#                         'station_id': 'a3a72012-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a9f76a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.921525,
#                         'legacy_id': '290',
#                         'lon': -87.707322,
#                         'name': 'Kedzie Ave & Palmer Ct',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13292',
#                         'station_id': 'a3a9f76a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b22d3d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.785861065132,
#                         'legacy_id': '561',
#                         'lon': -87.67414391040802,
#                         'name': 'Damen Ave & 59th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '561',
#                         'station_id': 'a3b22d3d-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3acb1de-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88445395657,
#                         'legacy_id': '378',
#                         'lon': -87.6962981368,
#                         'name': 'California Ave & Lake St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15666',
#                         'station_id': 'a3acb1de-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3ac7e9a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.83068856472101,
#                         'legacy_id': '367',
#                         'lon': -87.65621066093445,
#                         'name': 'Racine Ave & 35th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15446',
#                         'station_id': 'a3ac7e9a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b2862e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.751785,
#                         'legacy_id': '578',
#                         'lon': -87.578496,
#                         'name': 'Bennett Ave & 79th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '16970',
#                         'station_id': 'a3b2862e-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892048,
#                         'legacy_id': '643',
#                         'lon': -87.689397,
#                         'name': 'Smith Park',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '643',
#                         'station_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3aabad8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.92154,
#                         'legacy_id': '327',
#                         'lon': -87.653818,
#                         'name': 'Sheffield Ave & Webster Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1309000033',
#                         'station_id': 'a3aabad8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a62fc9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.845687,
#                         'legacy_id': '147',
#                         'lon': -87.622481,
#                         'name': 'Indiana Ave & 26th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1307000005',
#                         'station_id': 'a3a62fc9-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3af5d1c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.0085943972,
#                         'legacy_id': '467',
#                         'lon': -87.6904922389,
#                         'name': 'Western Ave & Lunt Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'RP-005',
#                         'station_id': 'a3af5d1c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a21de1a5-f5bc-4b50-8a13-aa28b7dcfa95',
#                         'has_kiosk': True,
#                         'lat': 41.719712183618824,
#                         'legacy_id': '700',
#                         'lon': -87.6430195569992,
#                         'name': 'Halsted St & 96th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '20105',
#                         'station_id': 'a21de1a5-f5bc-4b50-8a13-aa28b7dcfa95',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a99d47-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.857813,
#                         'legacy_id': '273',
#                         'lon': -87.62455,
#                         'name': 'Michigan Ave & 18th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13150',
#                         'station_id': 'a3a99d47-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b1d532-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880281,
#                         'legacy_id': '544',
#                         'lon': -87.774453,
#                         'name': 'Austin Blvd & Madison St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '16918',
#                         'station_id': 'a3b1d532-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b1fa1c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.808227,
#                         'legacy_id': '551',
#                         'lon': -87.67718,
#                         'name': 'Hoyne Ave & 47th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1504000091',
#                         'station_id': 'a3b1fa1c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91468,
#                         'legacy_id': '28',
#                         'lon': -87.64332,
#                         'name': 'Larrabee St & Menomonee St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000007',
#                         'station_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'f0f9f5dc-3d3f-4a32-aa3e-b87566e44de9',
#                         'has_kiosk': True,
#                         'lat': 41.7282338,
#                         'legacy_id': '684',
#                         'lon': -87.6675239,
#                         'name': 'Prospect Sq & 91st St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '20103',
#                         'station_id': 'f0f9f5dc-3d3f-4a32-aa3e-b87566e44de9',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'e63300bd-4ca3-4255-adfd-522289d68b8a',
#                         'has_kiosk': True,
#                         'lat': 41.741486528618054,
#                         'legacy_id': '687',
#                         'lon': -87.65841007232666,
#                         'name': 'Loomis Blvd & 84th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '20121',
#                         'station_id': 'e63300bd-4ca3-4255-adfd-522289d68b8a',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3ac9d43-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89841768945,
#                         'legacy_id': '374',
#                         'lon': -87.6865960164,
#                         'name': 'Western Ave & Walton St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1504000103',
#                         'station_id': 'a3ac9d43-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a60781db-2bec-4a15-a4a2-363297aefcec',
#                         'has_kiosk': True,
#                         'lat': 41.76160543804394,
#                         'legacy_id': '678',
#                         'lon': -87.64416097666071,
#                         'name': 'Halsted St & 73rd St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '20244',
#                         'station_id': 'a60781db-2bec-4a15-a4a2-363297aefcec',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899181,
#                         'legacy_id': '657',
#                         'lon': -87.6722,
#                         'name': 'Wood St & Augusta Blvd',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '657',
#                         'station_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3afb401-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.95400483876,
#                         'legacy_id': '484',
#                         'lon': -87.7191281797,
#                         'name': 'Monticello Ave & Irving Park Rd',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1504000139',
#                         'station_id': 'a3afb401-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a854bf-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.907626,
#                         'legacy_id': '236',
#                         'lon': -87.638566,
#                         'name': 'Sedgwick St & Schiller St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1307000143',
#                         'station_id': 'a3a854bf-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': '759171ce-f355-4740-948d-e14bb8f7dc0e',
#                         'has_kiosk': True,
#                         'lat': 41.65186780228521,
#                         'legacy_id': '704',
#                         'lon': -87.53967136144637,
#                         'name': 'Avenue O & 134th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '20214',
#                         'station_id': '759171ce-f355-4740-948d-e14bb8f7dc0e',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b23cb8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.775393,
#                         'legacy_id': '564',
#                         'lon': -87.654308,
#                         'name': 'Racine Ave & 65th St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '564',
#                         'station_id': 'a3b23cb8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3ad2d57-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.82301523798,
#                         'legacy_id': '407',
#                         'lon': -87.6265680185,
#                         'name': 'State St & Pershing Rd',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15449',
#                         'station_id': 'a3ad2d57-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3aa0bb7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.978353,
#                         'legacy_id': '294',
#                         'lon': -87.659753,
#                         'name': 'Broadway & Berwyn Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13109',
#                         'station_id': 'a3aa0bb7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3af2c5f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.98974251144,
#                         'legacy_id': '458',
#                         'lon': -87.6601406209,
#                         'name': 'Broadway & Thorndale Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15575',
#                         'station_id': 'a3af2c5f-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b2c87c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.94707089418471,
#                         'legacy_id': '591',
#                         'lon': -87.74000823497772,
#                         'name': 'Kilbourn Ave & Milwaukee Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '16994',
#                         'station_id': 'a3b2c87c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b13e66-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.872131,
#                         'legacy_id': '538',
#                         'lon': -87.746619,
#                         'name': 'Cicero Ave & Flournoy St',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '16912',
#                         'station_id': 'a3b13e66-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3ac3b03-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.01256011541,
#                         'legacy_id': '353',
#                         'lon': -87.6743671152,
#                         'name': 'Clark St & Touhy Ave',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'RP-007',
#                         'station_id': 'a3ac3b03-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a5de24-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.93953161982257,
#                         'legacy_id': '131',
#                         'lon': -87.6711143553257,
#                         'name': 'Lincoln Ave & Belmont Ave (Temp)',
#                         'region_id': '0',
#                         'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1309000042',
#                         'station_id': 'a3a5de24-a135-11e9-9cda-0a87ae2ba916',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b23785-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.779374,
#                         'legacy_id': '563',
# ...
#                         'client_station_id': 'motivate_CHI_1674190368396028570',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190368396028570',
#                         'has_kiosk': False,
#                         'lat': 41.705247,
#                         'legacy_id': '1674190368396028570',
#                         'lon': -87.701424,
#                         'name': 'Public Rack - Kedzie & 103rd St - W',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190368396028570',
#                         'station_type': 'lightweight'},
#                        {'address': 'Lee Elementary School, South Kildare '
#                                    'Avenue, West Elsdon, West Lawn, Chicago, '
#                                    'Lake Township, Cook County, Illinois, '
#                                    '60629, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1594041781399920504',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1594041781399920504',
#                         'has_kiosk': False,
#                         'lat': 41.7749163,
#                         'legacy_id': '1594041781399920504',
#                         'lon': -87.728841,
#                         'name': 'Tripp Ave & 65th St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1594041781399920504',
#                         'station_type': 'lightweight'},
#                        {'address': 'Harper High School, South Honore Street, '
#                                    'West Englewood, Chicago, Lake Township, '
#                                    'Cook County, Illinois, 60636, United '
#                                    'States',
#                         'capacity': 2,
#                         'client_station_id': 'motivate_CHI_1674190677633674406',
#                         'dockless_bikes_parking_zone_capacity': 2,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190677633674406',
#                         'has_kiosk': False,
#                         'lat': 41.775267,
#                         'legacy_id': '1674190677633674406',
#                         'lon': -87.669156,
#                         'name': 'Public Rack - William Rainey Harper High '
#                                 'School',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190677633674406',
#                         'station_type': 'lightweight'},
#                        {'address': 'Central Park Pumping Station, West '
#                                    'Fillmore Street, North Lawndale, Chicago, '
#                                    'Cook County, Illinois, 60624, United '
#                                    'States',
#                         'capacity': 1,
#                         'client_station_id': 'motivate_CHI_1674190230957074838',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190230957074838',
#                         'has_kiosk': False,
#                         'lat': 41.8680617,
#                         'legacy_id': '1674190230957074838',
#                         'lon': -87.7153897,
#                         'name': 'Public Rack - Central Park Ave & Fillmore St',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190230957074838',
#                         'station_type': 'lightweight'},
#                        {'address': '1451-1453, South Tripp Avenue, North '
#                                    'Lawndale, Chicago, Cook County, Illinois, '
#                                    '60623, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1561012887305957952',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1561012887305957952',
#                         'has_kiosk': False,
#                         'lat': 41.860777,
#                         'legacy_id': '1561012887305957952',
#                         'lon': -87.7313639,
#                         'name': 'Tripp Ave & 15th St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1561012887305957952',
#                         'station_type': 'lightweight'},
#                        {'address': '5528-5530, West Harrison Street, Austin, '
#                                    'Chicago, Cook County, Illinois, 60644, '
#                                    'United States',
#                         'capacity': 1,
#                         'client_station_id': 'motivate_CHI_1674190458590341928',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190458590341928',
#                         'has_kiosk': False,
#                         'lat': 41.87298,
#                         'legacy_id': '1674190458590341928',
#                         'lon': -87.763267,
#                         'name': 'Public Rack - Lotus Ave & Harrison St',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190458590341928',
#                         'station_type': 'lightweight'},
#                        {'address': '7000-7002, West Diversey Avenue, Beat '
#                                    '2512, Montclare, Chicago, Jefferson '
#                                    'Township, Cook County, Illinois, 60707, '
#                                    'United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1563698722681128992',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1563698722681128992',
#                         'has_kiosk': False,
#                         'lat': 41.9310084,
#                         'legacy_id': '1563698722681128992',
#                         'lon': -87.8010646,
#                         'name': 'Sayre & Diversey',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1563698722681128992',
#                         'station_type': 'lightweight'},
#                        {'address': 'Taylor Park Fieldhouse, 39, West 47th '
#                                    'Street, Grand Boulevard, Chicago, Lake '
#                                    'Township, Cook County, Illinois, 60609, '
#                                    'United States',
#                         'capacity': 2,
#                         'client_station_id': 'motivate_CHI_1674190621799099446',
#                         'dockless_bikes_parking_zone_capacity': 2,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190621799099446',
#                         'has_kiosk': False,
#                         'lat': 41.809085,
#                         'legacy_id': '1674190621799099446',
#                         'lon': -87.627384,
#                         'name': 'Public Rack - State St & 47th st',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190621799099446',
#                         'station_type': 'lightweight'},
#                        {'address': "Dunkin', 207, West 79th Street, Auburn "
#                                    'Park, Chatham, Chicago, Lake Township, '
#                                    'Cook County, Illinois, 60620, United '
#                                    'States',
#                         'capacity': 1,
#                         'client_station_id': 'motivate_CHI_1674190656158837882',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190656158837882',
#                         'has_kiosk': False,
#                         'lat': 41.750712,
#                         'legacy_id': '1674190656158837882',
#                         'lon': -87.629949,
#                         'name': 'Public Rack - Wentworth Ave & 79th St',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190656158837882',
#                         'station_type': 'lightweight'},
#                        {'address': '1132, East 44th Street, Kenwood, Chicago, '
#                                    'Hyde Park Township, Cook County, Illinois, '
#                                    '60653, United States',
#                         'capacity': 1,
#                         'client_station_id': 'motivate_CHI_1674190428525570800',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190428525570800',
#                         'has_kiosk': False,
#                         'lat': 41.814697,
#                         'legacy_id': '1674190428525570800',
#                         'lon': -87.598006,
#                         'name': 'Public Rack - Lake Park Ave & 44th St',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190428525570800',
#                         'station_type': 'lightweight'},
#                        {'address': '3333-3339, West Belmont Avenue, Avondale, '
#                                    'Chicago, Jefferson Township, Cook County, '
#                                    'Illinois, 60618, United States',
#                         'capacity': 6,
#                         'client_station_id': 'motivate_CHI_1674190239547009458',
#                         'dockless_bikes_parking_zone_capacity': 6,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1674190239547009458',
#                         'has_kiosk': False,
#                         'lat': 41.93917,
#                         'legacy_id': '1674190239547009458',
#                         'lon': -87.71169,
#                         'name': 'Public Rack - Christiana Ave & Belmont Ave',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1674190239547009458',
#                         'station_type': 'lightweight'},
#                        {'address': '3711-3719, West Roosevelt Road, North '
#                                    'Lawndale, Chicago, Cook County, Illinois, '
#                                    '60624, United States',
#                         'capacity': 1,
#                         'client_station_id': 'motivate_CHI_1715846705501012842',
#                         'dockless_bikes_parking_zone_capacity': 1,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1715846705501012842',
#                         'has_kiosk': False,
#                         'lat': 41.8662123,
#                         'legacy_id': '1715846705501012842',
#                         'lon': -87.7184969,
#                         'name': 'Public Rack - Independence Blvd & Roosevelt',
#                         'rack_model': 'CITY_PUBLIC_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1715846705501012842',
#                         'station_type': 'lightweight'}]},
#  'last_updated': 1666047251,
#  'ttl': 5}

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")
#
# NameError: name 'psycopg2' is not defined

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
#       3 cursor = db_connection.cursor()
#
# NameError: name 'db_connection' is not defined

# %%
# uncomment the following line if you already created the database 
# Only once you need to create the database

cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
db_connection.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       1 # uncomment the following line if you already created the database
#       2 # Only once you need to create the database
# ----> 4 cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
#       5 db_connection.commit()
#
# NameError: name 'cursor' is not defined

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="root")

cursor = db_connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="root")
#       3 cursor = db_connection.cursor()
#
# NameError: name 'psycopg2' is not defined

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension

cursor.execute("CREATE EXTENSION postgis;")

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id BIGINT,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        if not ((df__stations['legacy_id'].iloc[x]).isnumeric()) :
            continue
        
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            df__stations['legacy_id'].iloc[x],
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

    print(row)
        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype('int64')
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    now = datetime.now()
    timedate = ( (str(now.now())).split('.')[0]).split(' ')[0] + ' ' + ((str(now.now())).split('.')[0]).split(' ')[1]
 
    print(timedate, ' : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...')
    time.sleep(120)    
    continue

# %%
# close connection at the end of the script

db_connection.close()
